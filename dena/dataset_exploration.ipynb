# %%
import pandas as pd

df = pd.read_csv("/home/dena/STEMdays/alecioc/data/10k_random_tracks.csv")

# %%
df_from_file = pd.read_csv("/home/dena/STEMdays/alecioc/data/10k_random_tracks.csv")
df_from_file.head()
# Out:
#    Unnamed: 0                      id                                    name  \
# 0      129583  6OxxzC0HsX7zK3ZO3q79H6                               traveling
# 1      403270  4TXLc6kN0HOIItpWigjcTk                   Airmata Saksi Cintaku
# 2        2762  6C0k7xIhe3DakNTtSuVfnz  Kapitel 64 - Der Page und die Herzogin
# 3      228616  5oBsB671s34iG8A2v8exQB                            Ma De Ginete
# 4      267528  5GPFKWYO8GnGJktBXj8PEm                               Armstrong
#
#    popularity  duration_ms  explicit                              artists  \
# 0          55       313547         0                     ['Hikaru Utada']
# 1          21       347947         0                          ['Lestari']
# 2           1       127936         0  ['Georgette Heyer', 'Irina Salkow']
# 3          44       243307         0                    ['Antonis Remos']
# 4          28       162587         0                             ['Lobo']
#
# ...

# %%
lista_di_colonne = ["name", "popularity"]
df_from_file[lista_di_colonne]
# Out:
#                                             name  popularity
# 0                                      traveling          55
# 1                          Airmata Saksi Cintaku          21
# 2         Kapitel 64 - Der Page und die Herzogin           1
# 3                                   Ma De Ginete          44
# 4                                      Armstrong          28
# ...                                          ...         ...
# 9995                           Ghungru Tutale Re          10
# 9996  Capítulo 18.2 - la Sombra Fuera del Tiempo           0
# 9997                               Gelin Ne Olur          36
# 9998                Sing A Sad Song - Remastered          17
# 9999                        La Cuerda Planetaria          32
#
# [10000 rows x 2 columns]

# %%
df_from_file["name"]
# Out:
# 0                                        traveling
# 1                            Airmata Saksi Cintaku
# 2           Kapitel 64 - Der Page und die Herzogin
# 3                                     Ma De Ginete
# 4                                        Armstrong
#                            ...
# 9995                             Ghungru Tutale Re
# 9996    Capítulo 18.2 - la Sombra Fuera del Tiempo
# 9997                                 Gelin Ne Olur
# 9998                  Sing A Sad Song - Remastered
# 9999                          La Cuerda Planetaria
# Name: name, Length: 10000, dtype: object

# %%
lista_di_righe = [3,4,5]
df_from_file.iloc[lista_di_righe]
# Out:
#    Unnamed: 0                      id          name  popularity  duration_ms  \
# 3      228616  5oBsB671s34iG8A2v8exQB  Ma De Ginete          44       243307
# 4      267528  5GPFKWYO8GnGJktBXj8PEm     Armstrong          28       162587
# 5      586190  0XOdkTR7yRx41OrHmCqkxl         對得起自己          16       227000
#
#    explicit            artists                  id_artists release_date  \
# 3         0  ['Antonis Remos']  ['6s26Q38Zqc4hY3xe7jrEBG']   2003-10-23
# 4         0           ['Lobo']  ['1sldhz8tzC100cRAdfnMht']   1975-01-01
# 5         0    ['Jackie Chan']  ['0wVKXWiOMLfqmFCdCPR7Ar']   1995-01-21
#
#    danceability  ...  key  loudness  mode  speechiness  acousticness  \
# 3         0.742  ...   10    -4.697     0       0.0829        0.1460
# 4         0.552  ...    2   -13.193     1       0.0288        0.4240
# 5         0.620  ...    3    -6.964     0       0.0513        0.0365
#
#    instrumentalness  liveness  valence    tempo  time_signature
# ...

# %%
df["danceability"].hist()

# %%
df_from_file[df_from_file["danceability"] > 0.8]
# Out:
#       Unnamed: 0                      id  \
# 16        513639  359WCtca6toka8DA4rhkAQ
# 29        192829  1Zy8GkiHyaElZ61pok8jRP
# 36        491898  7tHI3TNDq2HhMTqJuRG2uw
# 44        115354  5FG7Tl93LdH117jEKYl3Cm
# 55        213408  2m6Fo52AVEPFUKPnTj6QIy
# ...          ...                     ...
# 9877      421244  006wcXrEjCS2O5nX6T7QWA
# 9926      263892  5sgereBjwhDAqylhd8ksjz
# 9944      378452  3O63PDUHZHWVi4m6lBGogG
# 9973      317156  3OLmGz1XkjFotGTwyOHOWg
# 9987      418388  3FdDCSSWJZhB360iypit76
#
#                                               name  popularity  duration_ms  \
# 16                   Nana Se Kahti Thi Nani Humare           0       181055
# 29               001 - beim Wanderzirkus - Teil 39          30        66573
# 36    Genie In A Bottle - Flavio vs. Mad Boris Mix          35       390333
# 44                            Essence (feat. Tems)          68       248040
# 55                                   Siga La Gente          10       161627
# ...

# %%
df["release_date"] = pd.to_datetime(df["release_date"])
df["release_year"] = df["release_date"].dt.year
to_plot = df.groupby("release_year")["danceability"].mean()
to_plot
# Out:
# release_year
# 1922    0.373667
# 1923    0.645812
# 1924    0.572750
# 1925    0.581533
# 1926    0.612321
#           ...
# 2017    0.600000
# 2018    0.618073
# 2019    0.659987
# 2020    0.644892
# 2021    0.662519
# Name: danceability, Length: 100, dtype: float64

# %%
df_from_file.sort_values("popularity")
# Out:
#                             id                                          name  \
# 546130  181rTRhCcggZPwP2TUcVqm  Newspaper Reports On Abner, 20 February 1935
# 546222  0yOCz3V5KMm8l1T8EFc60i                                        恋は水の上で
# 546221  0y48Hhwe52099UqYjegRCO                                         私の誕生日
# 546220  0xCmgtf9ka07hkZg3D6PaV                           エル・チョクロ (EL CHOCLO)
# 546219  0tBXS3VuCPX7KWUFH2nros                                      恋は不思議なもの
# ...                        ...                                           ...
# 92811   6tDDoYIxWvMLTdKpjFkc1B                                     telepatía
# 92810   5QO79kh1waicV47BqGRL3g                               Save Your Tears
# 93804   3Ofmpyhv5UAQ70mENzB277                        Astronaut In The Ocean
# 93803   7lPN2DXiMsVn7XUKtOW1CS                               drivers license
# 93802   4iJyoBOLtHqaGxP12qzhQI        Peaches (feat. Daniel Caesar & Giveon)
#
#         popularity  duration_ms  explicit  \
# ...

# %%
df[df["popularity"] == 99]
# Out:
#                            id             name  popularity  duration_ms  \
# 93803  7lPN2DXiMsVn7XUKtOW1CS  drivers license          99       242014
#
#        explicit             artists                  id_artists release_date  \
# 93803         1  ['Olivia Rodrigo']  ['1McMsnEElThX1knmY4oliG']   2021-01-08
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 93803         0.585   0.436  ...    -8.761     1       0.0601         0.721
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 93803          0.000013     0.105    0.132  143.874               4
#
#        release_year
# 93803          2021
#
# [1 rows x 21 columns]

# %%
df_grouped = df_from_file.groupby("popularity")["energy"].mean()
print(df_grouped)
# Out:
# popularity
# 0      0.356308
# 1      0.406060
# 2      0.440914
# 3      0.451192
# 4      0.447878
#          ...
# 96     0.673000
# 97     0.675000
# 98     0.695000
# 99     0.436000
# 100    0.696000
# Name: energy, Length: 101, dtype: float64

# %%
df_from_file["duration_ms"].max()/1000/60
# Out:
# 93.68696666666666

# %%
df_from_file[df_from_file['name'] == "Juice"]
# Out:
#                             id   name  popularity  duration_ms  explicit  \
# 92145   0k664IuFwVP557Gnx7RhIl  Juice          78       195145         1
# 295234  0VxaQOPxoA8rLpMMNLdfav  Juice          45        63425         0
# 344992  4JeL0AB8sCthmoQW9zFmCZ  Juice          47       180168         1
# 491965  2630LGFzVc6CfhthvQ800k  Juice           1       211213         0
#
#                          artists  \
# 92145                  ['Lizzo']
# 295234              ['New Gene']
# 344992                    ['Aj']
# 491965  ['Young Franco', 'Pell']
#
#                                                id_artists release_date  \
# 92145                          ['56oDRnqbIiwx4mymNEv7dS']   2019-04-19
# 295234                         ['1nqzKo5i5Bxch07kQ39gSK']   2019-11-19
# 344992                         ['4q70E2kURlN8nho66GuXU2']   2020-04-20
# 491965  ['6mK0vAO13gT8jWYANyoXAl', '2O2dI9lY9PnWtAa4Ol...   2020-09-25
#
# ...

# %%
df_from_file["release_date"] = pd.to_datetime(df_from_file["release_date"])
df_2019 = df_from_file[
                        (df_from_file["release_date"] > "2019-01-01") & \
                        (df_from_file["release_date"] < "2020-01-01")
                      ]
df_2019.head()
# Out:
#                            id                                   name  \
# 73439  4zP7ADsgJgHGY6VzxbNp1z                              Year 3000
# 73443  6VfAg1vxowOt4KmAMhmimP                              Year 3000
# 73447  1bd0GHWmB4ZhPsdIUU6hp4                              Year 3000
# 73485  5Q8lhXskGhfVIMbRMGi9nk          Logical Brain - Year 3000 Mix
# 73489  6GEOjP12NG6wnuQIg6NC5A  3000 Years of Lies - Original Version
#
#        popularity  duration_ms  explicit             artists  \
# 73439          67       201960         0  ['Jonas Brothers']
# 73443          37       201960         0  ['Jonas Brothers']
# 73447          19       352435         0          ['Artica']
# 73485           8       216705         0    ['Electro Mann']
# 73489           9       308824         0             ['UVB']
#
#                        id_artists release_date  danceability  energy  ...  \
# 73439  ['7gOdHgIoIKoe4i9Tta6qdD']   2019-05-09         0.659   0.857  ...
# ...

# %%
df['popularity'].max()
# Out:
# 100

# %%
mean_duration_ms = df_2019["duration_ms"].mean()
mean_duration_s = mean_duration_ms/1000
mean_duration_min = mean_duration_s/60
print(mean_duration_min)
# Out:
# 3.6143411844103257

# %%
df_from_file["release_date"] = pd.to_datetime(df_from_file["release_date"])
df_from_file["release_year"] = df_from_file["release_date"].dt.year
df_2019 = df_from_file[df_from_file["release_year"] == 2019]
df_2019.head()
# Out:
#                            id                                   name  \
# 73439  4zP7ADsgJgHGY6VzxbNp1z                              Year 3000
# 73443  6VfAg1vxowOt4KmAMhmimP                              Year 3000
# 73447  1bd0GHWmB4ZhPsdIUU6hp4                              Year 3000
# 73485  5Q8lhXskGhfVIMbRMGi9nk          Logical Brain - Year 3000 Mix
# 73489  6GEOjP12NG6wnuQIg6NC5A  3000 Years of Lies - Original Version
#
#        popularity  duration_ms  explicit             artists  \
# 73439          67       201960         0  ['Jonas Brothers']
# 73443          37       201960         0  ['Jonas Brothers']
# 73447          19       352435         0          ['Artica']
# 73485           8       216705         0    ['Electro Mann']
# 73489           9       308824         0             ['UVB']
#
#                        id_artists release_date  danceability  energy  ...  \
# 73439  ['7gOdHgIoIKoe4i9Tta6qdD']   2019-05-09         0.659   0.857  ...
# ...

# %%
mean_duration_ms = df_2019["duration_ms"].mean()
mean_duration_s = mean_duration_ms/1000
mean_duration_min = mean_duration_s/60
print(mean_duration_min)
# Out:
# 3.6133725441616975

# %%
df[df['duration_ms'] == df['duration_ms'].max()]
# Out:
#                             id                               name  popularity  \
# 326329  3EEv9UCeZdn4MVFv8tsO1E  โครงสร้างแห่งสิ่งที่เรียกว่าชีวิต           3
#
#         duration_ms  explicit          artists                  id_artists  \
# 326329      5621218         0  ['ท่านพุทธทาส']  ['2ySk9zib3PuomvMGmCqdTA']
#
#        release_date  danceability  energy  key  loudness  mode  speechiness  \
# 326329   1979-07-28         0.638   0.537    8   -13.365     1        0.775
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 326329         0.825               0.0     0.345    0.401  131.446
#
#         time_signature
# 326329               3

# %%
df.loc[df['duration_ms'].idxmax()]
# Out:
# id                             3EEv9UCeZdn4MVFv8tsO1E
# name                โครงสร้างแห่งสิ่งที่เรียกว่าชีวิต
# popularity                                          3
# duration_ms                                   5621218
# explicit                                            0
# artists                               ['ท่านพุทธทาส']
# id_artists                 ['2ySk9zib3PuomvMGmCqdTA']
# release_date                               1979-07-28
# danceability                                    0.638
# energy                                          0.537
# key                                                 8
# loudness                                      -13.365
# mode                                                1
# speechiness                                     0.775
# acousticness                                    0.825
# instrumentalness                                    0
# liveness                                        0.345
# ...

# %%
df_from_file.loc[df_from_file["danceability"] > 0.8, "name"]
# Out:
# 72                   Capítulo 2.14 - Banquero Anarquista
# 150                                         Weather Bird
# 215                                 I Must Have That Man
# 231                                               T.N.T.
# 527                                      Sleepy Time Gal
#                                ...
# 586529    Head Shoulders Knees & Toes Kids Exercise Song
# 586533                                              午夜DJ
# 586554                                Fly, Fly Butterfly
# 586562                     The Muffin Man - 2012 Version
# 586632                                 Itsy Bitsy Spider
# Name: name, Length: 37316, dtype: object

# %%
df = pd.DataFrame(index="person 1")

# %%
df_small = df[["name", "popularity", "duration_ms", "release_date", "danceability"]].sample(n=20, random_state=41).sort_values("release_date").reset_index(drop=True)

# %%
dff = df[["name", "popularity", "duration_ms", "release_date", "danceability"]].sample(n=20, random_state=41).sort_values("release_date").reset_index(drop=True)
dff["release_date"] = pd.to_datetime(dff["release_date"])
dff = dff.set_index("release_date")
dff
# Out:
#                                                            name  popularity  \
# release_date
# 1952-01-01        La traviata*: Act II: Un di, quando le veneri           0
# 1954-01-01               Messa da Requiem: Libera me: Libera me           0
# 1962-11-12                                I Don't Wanna Be Tied          24
# 1965-09-11                    034 - Der Struwwelpeter - Teil 04           8
# 1971-01-01                                     Geçmesin Günümüz          11
# 1971-01-01                             Eu La Mândra Când Mă Duc           3
# 1978-01-01                                 Juan José Montemayor          24
# 1982-01-01                                     Himig Panglangit          12
# 1984-06-01    031 - Die Entführung in der Mondscheingasse - ...          29
# 1991-01-01                 Women in Love - From 'Women in Love'          34
# 1997-08-25                                              Du hast          68
# ...

# %%
df_from_list = pd.DataFrame(["a", "b", "c", "d"])
df_from_list
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
df_from_list = pd.DataFrame(
    ["a", "b", "c", "d"], 
    columns=["lettere"]
)

print(df_from_list)
